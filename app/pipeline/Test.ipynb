# %%
import pandas as pd
from sqlalchemy import create_engine
import pyarrow.parquet as pq
df = pd.read_parquet('green_tripdata_2025-11.parquet')
df.head(100)

for col, dtype in df.dtypes.items():
    if "int" in str(dtype):
        dtype_map[col] = "int32"
    elif "float" in str(dtype):
        dtype_map[col] = "float64"
    elif "datetime" in str(dtype):
        dtype_map[col] = "datetime64[us]"
    else:
        dtype_map[col] = "string"
for k, v in dtype_map.items():
    print(f'    "{k}": "{v}",')
parquet_file = pq.ParquetFile('green_tripdata_2025-11.parquet')

engine = create_engine('postgresql+psycopg://root:root@localhost:5433/aegley_db')
# for batch in parquet_file.iter_batches(batch_size=100000):
#     df = batch.to_pandas()
#     df.to_sql(
#         name = 'green_teripdata_2025-11',
#         con=engine,
#         if_exists='replace'
#     )

# df.to_sql(name = 'green_teripdata_2025-11', con=engine, if_exists='append')

print(len(df))
# Out:
# 46912
